# %%
try:    
    # !jupyter nbconvert --to python train.ipynb
    # python即转化为.py，script即转化为.html
    # file_name.ipynb即当前module的文件名
except:
    pass
# Out:
# [NbConvertApp] Converting notebook train.ipynb to python
# [NbConvertApp] Writing 3580 bytes to train.py
