# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 5, 0.1) + 0.1
y1 = np.log(x)
y2 = np.log(2)
y3 = np.log(3)
y4 = np.log(10)
y5 = np.log(1.5)
y6 = np.log(1.2)

plt.plot(x, y1/y2)
plt.plot(x, y1/y3)
plt.plot(x, y1/y4)
plt.plot(x, y1/y5)
plt.plot(x, y1/y6)
plt.plot()
plt.scatter([2, ], [1, ], s=100, color='b')
plt.plot([0, 5,], [1, 1,], 'k--', linewidth=1)
plt.show()
